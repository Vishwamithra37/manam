# %%
#The imports which work for the whole notebook
import requests
from nested_dictionaries import NestedDictionaries as nd #Black magic module everyone should consider

a1=nd()
a1['auth']['login']='vita19'
a1['auth']['password']='Vishrutha37'
print(a1)
r1 = requests.post('http://localhost:5000/register', json=a1)
beta1=r1.json()                      #REturns the shit in dictionary format
print(beta1)
# Out:
# {'auth': {'login': 'vita19', 'password': 'Vishrutha37'}}
# {'Juula': 'Maaya'}

# %%
#Create server code

r2=requests.get('https://rest.citycloud.com/compute/v1/flavors/fra1/Default Project 39140', headers=a2)
print(r2.text)
# Out:
# [
#   {
#     "id": "001a7567-8e52-4e1d-80c1-2cc91b59e844",
#     "name": "24C-12GB-20GB",
#     "ram": 12288,
#     "disk": 20,
#     "swap": "",
#     "OS-FLV-EXT-DATA:ephemeral": 0,
#     "OS-FLV-DISABLED:disabled": false,
#     "vcpus": 24,
#     "os-flavor-access:is_public": true,
#     "rxtx_factor": 1,
#     "links": [
#       {
#         "rel": "self",
#         "href": "https:\/\/fra1.citycloud.com:8774\/v2\/17cfdd9518084be397925b3b72de2967\/flavors\/001a7567-8e52-4e1d-80c1-2cc91b59e844"
#       },
#       {
#         "rel": "bookmark",
#         "href": "https:\/\/fra1.citycloud.com:8774\/17cfdd9518084be397925b3b72de2967\/flavors\/001a7567-8e52-4e1d-80c1-2cc91b59e844"
#       }
#     ],
#     "ramGB": 12
#   },
#   {
#     "id": "00a71193-eb77-4356-9879-73dcabb39e70",
#     "name": "4C-128GB-200GB",
#     "ram": 131072,
#     "disk": 200,
#     "swap": "",
#     "OS-FLV-EXT-DATA:ephemeral": 0,
#     "OS-FLV-DISABLED:disabled": false,
#     "vcpus": 4,
# ...

# %%
print(a2)
r3=requests.get('https://rest.citycloud.com/accesscontrol/v1/openstack/domains', headers=a2)
print(r3.text)
# Out:
# {'X-AUTH-LOGIN': 'vita19', 'X-AUTH-TOKEN': 'Dp4SigIuhiltHiD36c1QEXDyBNU6HCty'}
# [
#   {
#     "area": {
#       "id": "7",
#       "name": "Germany \/ Frankfurt",
#       "tag": "DE",
#       "regions": [
#         {
#           "zone_id": "6",
#           "name": "Frankfurt \/ Germany",
#           "status": "active",
#           "region": "Fra1"
#         }
#       ]
#     },
#     "id": "99c442651eb84358a515c42e4e6b3acb",
#     "status": "provisioned",
#     "name": "CCP_Domain_39140",
#     "enabled": true
#   },
#   {
#     "area": {
#       "id": "3",
#       "name": "Japan",
#       "tag": "JP",
#       "regions": [
#         {
#           "zone_id": "7",
#           "name": "Tokyo \/ Japan",
#           "status": "active",
#           "region": "tky1"
#         }
#       ]
#     },
#     "status": "available"
#   },
#   {
#     "area": {
#       "id": "6",
#       "name": "Sweden \/ Stockholm",
#       "tag": "SE_STO2",
#       "regions": [
#         {
# ...

# %%
from flask import Flask,jsonify,request
app=Flask(__name__)
@app.route('/a1',methods=['POST'])
def js():
    data= request.
    
    return jsonify(data)
